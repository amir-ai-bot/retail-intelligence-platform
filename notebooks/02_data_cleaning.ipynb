# %% [markdown]
# # Data Cleaning Review
#
# This notebook is for reviewing outputs created by `src/transform.py`, including cleaned files and the data quality report.

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == 'notebooks':
    PROJECT_ROOT = PROJECT_ROOT.parent
report_path = PROJECT_ROOT / 'data' / 'processed' / 'reports' / 'data_quality_report.csv'
if report_path.exists():
    display(pd.read_csv(report_path))
else:
    print('Run src/transform.py to generate the data quality report.')
