# %% [markdown]
# # Data Exploration
#
# Use this notebook to inspect raw retail datasets before running the cleaning pipeline. Keep large data files local under `data/raw/`.

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == 'notebooks':
    PROJECT_ROOT = PROJECT_ROOT.parent
RAW_DIR = PROJECT_ROOT / 'data' / 'raw'
RAW_DIR
