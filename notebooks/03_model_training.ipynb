# %% [markdown]
# # Model Training Notes
#
# Use this notebook to review baseline forecasting metrics generated by `src/train_model.py`.

# %%
from pathlib import Path
import json

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == 'notebooks':
    PROJECT_ROOT = PROJECT_ROOT.parent
metrics_path = PROJECT_ROOT / 'models' / 'walmart_weekly_sales_metrics.json'
if metrics_path.exists():
    print(json.dumps(json.loads(metrics_path.read_text()), indent=2))
else:
    print('Run src/train_model.py to generate model metrics.')
